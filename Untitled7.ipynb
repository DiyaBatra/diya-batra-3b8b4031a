# %% [markdown]
# <a href="https://colab.research.google.com/github/DiyaBatra/diya-batra-3b8b4031a/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive
# Out:
#  Bday+pinjore	    Grba	   IMG_2395.JPG  'Untitled folder'
# 'Colab Notebooks'   IMG_2387.JPG   IMG_2397.JPG  'Untitled form.gform'
#  dataset	    IMG_2389.JPG   IMG_2398.JPG
#  Diwali		    IMG_2390.JPG   Palak
#  Garba		    IMG_2393.JPG   School

# %%
# !ls /content/drive/MyDrive/dataset'Industrial fire dataset.zip'
# Out:
# ls: cannot access '/content/drive/MyDrive/datasetIndustrial fire dataset.zip': No such file or directory

# %%
zip_path = "/content/drive/MyDrive/dataset/Industrial fire dataset.zip"

# %%
import zipfile

zip_path = "/content/drive/MyDrive/dataset/Industrial fire dataset.zip"
extract_path = "/content/fire_dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction Done ✅")
# Out:
# Extraction Done ✅

# %%
import os

for root, dirs, files in os.walk("/content/fire_dataset"):
    print(root)
    print("Folders:", dirs)
    print("Files:", files[:5])
    print("-"*40)
# Out:
# /content/fire_dataset
# Folders: ['Industrial fire dataset']
# Files: []
# ----------------------------------------
# /content/fire_dataset/Industrial fire dataset
# Folders: ['data']
# Files: ['data.yaml']
# ----------------------------------------
# /content/fire_dataset/Industrial fire dataset/data
# Folders: ['test', 'train', 'val']
# Files: []
# ----------------------------------------
# /content/fire_dataset/Industrial fire dataset/data/test
# Folders: ['images', 'labels']
# Files: []
# ----------------------------------------
# /content/fire_dataset/Industrial fire dataset/data/test/images
# Folders: []
# Files: ['AoF07813.jpg', 'AoF07680.jpg', 'WEB11716.jpg', 'AoF06861.jpg', 'AoF07321.jpg']
# ----------------------------------------
# /content/fire_dataset/Industrial fire dataset/data/test/labels
# Folders: []
# Files: ['WEB10655.txt', 'AoF07194.txt', 'PublicDataset01170.txt', 'WEB10941.txt', 'AoF07408.txt']
# ----------------------------------------
# ...

# %%
import os

base_path = "/content/fire_dataset/Industrial fire dataset/data"
output_path = "/content/processed_dataset"

splits = ["train", "val"]

for split in splits:
    os.makedirs(f"{output_path}/{split}/fire", exist_ok=True)
    os.makedirs(f"{output_path}/{split}/non_fire", exist_ok=True)

print("Folders Created ✅")
# Out:
# Folders Created ✅

# %%
import shutil

for split in ["train", "val"]:
    img_dir = f"{base_path}/{split}/images"
    label_dir = f"{base_path}/{split}/labels"

    for img_file in os.listdir(img_dir):
        img_path = os.path.join(img_dir, img_file)
        label_file = img_file.replace(".jpg", ".txt")
        label_path = os.path.join(label_dir, label_file)

        # If label file exists and NOT empty → fire
        if os.path.exists(label_path) and os.path.getsize(label_path) > 0:
            shutil.copy(img_path, f"{output_path}/{split}/fire")
        else:
            shutil.copy(img_path, f"{output_path}/{split}/non_fire")

print("Conversion Done ✅")
# Out:
# Conversion Done ✅

# %%
for split in ["train", "val"]:
    print(split)
    print("Fire:", len(os.listdir(f"{output_path}/{split}/fire")))
    print("Non-Fire:", len(os.listdir(f"{output_path}/{split}/non_fire")))
    print("-"*30)
# Out:
# train
# Fire: 7664
# Non-Fire: 6458
# ------------------------------
# val
# Fire: 1724
# Non-Fire: 1375
# ------------------------------

# %%
train_dir = "/content/processed_dataset/train"
val_dir = "/content/processed_dataset/val"

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %%
train_dir = "/content/processed_dataset/train"
val_dir = "/content/processed_dataset/val"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    zoom_range=0.1,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='binary'
)

val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 14122 images belonging to 2 classes.
# Found 3099 images belonging to 2 classes.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report, confusion_matrix

# %%
train_dir = "/content/processed_dataset/train"
val_dir = "/content/processed_dataset/val"

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    zoom_range=0.1,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='binary'
)

val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 14122 images belonging to 2 classes.
# Found 3099 images belonging to 2 classes.

# %%
print(train_gen.class_indices)
# Out:
# {'fire': 0, 'non_fire': 1}

# %%
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable = False  # freeze

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10
)
# Out:
# Epoch 1/10
#   2/442 ━━━━━━━━━━━━━━━━━━━━ 26:08 4s/step - accuracy: 0.7422 - loss: 0.5178
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18528/3819985917.py in <cell line: 0>()
# ----> 1 history = model.fit(
#       2     train_gen,
#       3     validation_data=val_gen,
#       4     epochs=10
#       5 )
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...
